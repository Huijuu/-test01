# %% [markdown]
# # 104年度臺北市交通流量及特性調查
# http://163.29.251.188/botedata/%E4%BA%A4%E9%80%9A%E6%B5%81%E9%87%8F/104%E5%B9%B4%E5%BA%A6/104%E5%B9%B4%E5%BA%A6%E8%87%BA%E5%8C%97%E5%B8%82%E4%BA%A4%E9%80%9A%E6%B5%81%E9%87%8F%E5%8F%8A%E7%89%B9%E6%80%A7%E8%AA%BF%E6%9F%A5.htm
# NI075	南京東路~松江路
# NI076	南京東路~林森北路
# NI077	南京東路~堤頂大道
# NI078	南京東路~舊宗路

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "http://163.29.251.188/botedata/%E4%BA%A4%E9%80%9A%E6%B5%81%E9%87%8F/104%E5%B9%B4%E5%BA%A6/%E8%B7%AF%E5%8F%A3/NI075.files/sheet003.htm"
res = requests.get(url)
res.encoding='big5'
soup = BeautifulSoup(res.text,'html5lib')
ele = soup.select('table tbody tr')
print ele
# Out:
# [<tr height="30" style="mso-height-source:userset;height:23.1pt">\n  <td class="xl65" height="30" style="height:23.1pt;width:25pt" width="34"></td>\n  <td class="xl66" style="width:45pt" width="60">\u7ad9\u3000\u865f\uff1a</td>\n  <td class="xl65" style="width:40pt" width="53">NI075</td>\n  <td class="xl65" style="width:40pt" width="53"></td>\n  <td class="xl65" style="width:40pt" width="53"></td>\n  <td class="xl65" style="width:40pt" width="53"></td>\n  <td class="xl65" style="width:40pt" width="53"></td>\n  <td class="xl65" style="width:40pt" width="53"></td>\n  <td class="xl65" style="width:40pt" width="53"></td>\n  <td class="xl65" style="width:40pt" width="53"></td>\n  <td class="xl66" style="width:9pt" width="12">\u65e5\u671f\uff1a</td>\n  <td class="xl65" colspan="3" style="mso-ignore:colspan;width:120pt" width="159">104/06/10(Wed)</td>\n  <td class="xl65" style="width:40pt" width="53"></td>\n  <td class="xl65" style="width:40pt" width="53"></td>\n  <td class="xl65" style="wi
# ...

# %% [markdown]
# ## 交通尖峰時段

# %%
ele_time = soup.select('tbody tr td.xl72')
print len(ele_time)
for i in xrange(0,len(ele_time)):
    print ele_time[i].text
# Out:
# 39
# 07:00-08:00
# 08:00-09:00
# 17:00-18:00
# 18:00-19:00
#
#
# 07:00-08:00
# 08:00-09:00
# 17:00-18:00
# 18:00-19:00
#
#
# 07:00-08:00
# 08:00-09:00
# 17:00-18:00
# 18:00-19:00
#
#
# 07:00-08:00
# 08:00-09:00
# 17:00-18:00
# 18:00-19:00
#
#
# 合計
# 07:00-08:00
# 08:00-09:00
# 17:00-18:00
# 18:00-19:00
# 08:00-09:00
#
#
#
#
#
#
#
#
# 17:45-18:45

# %% [markdown]
# ## 尖峰時段___各方向____數值

# %%
ele_align = soup.select('tbody tr td.xl65')
print len(ele_align)

for i in xrange(0,len(ele_align)):
    print ele_align[i].text

# print ele_align
# Out:
# 913
#
# NI075
#
#
#
#
#
#
#
# 104/06/10(Wed)
#
#
#
# 1.AC方向
#   禁止左轉(公車除外)
#
#
#
#
#
#
#
#
#
# 南京東路~松江路
#
#
#
#
#
# 晴
#
#
#
#
#
#
# 2.BD方向 禁止左轉
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 公車表公車專用道公車流量
#
#
#
# 3.ABCD方向有公車專用道
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0
# 6
# 0
# 0
# 12
# 76
#
# 13
# 109
# 558
# 663
# 1056
#
# 3
# 0
# 88
# 45
# 126
#
# 131
# 646
# 708
# 1194
#
# 0
# 7
# 0
# 0
# 14
# 119
#
# 28
# 121
# 859
# 1239
# 1648
#
# 3
# 0
# 139
# 61
# 189
#
# 159
# 998
# 1300
# 1851
#
# 0
# 7
# 0
# 0
# 14
# 186
#
# 10
# 100
# 703
# 1547
# 1551
#
# 5
# 0
# 168
# 90
# 240
#
# 122
# 871
# 1637
# 1805
#
# 0
# 6
# 0
# 0
# 12
# 217
#
# 11
# 98
# 842
# 1910
# 1840
#
# 2
# 0
# 157
# 112
# 231
#
# 117
# 999
# 2022
# 2083
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 93
#
# 16
# 58
# 440
# 881
# 943
#
# 7
# 0
# 109
# 107
# 190
#
# 81
# ...

# %% [markdown]
# ## 尖峰時段___各方向____比重

# %%
ele_align_p = soup.select('tbody tr td.xl116')
print len(ele_align_p)

for i in xrange(0,len(ele_align_p)):
    print ele_align_p[i].text
# Out:
# 192
# 1%
# 88%
# 11%
# 9%
# 44%
# 47%
# 1%
# 89%
# 10%
# 6%
# 41%
# 53%
# 1%
# 86%
# 13%
# 5%
# 33%
# 62%
# 1%
# 88%
# 11%
# 4%
# 32%
# 64%
#
#
#
#
#
#
# 0%
# 83%
# 17%
# 5%
# 34%
# 61%
# 0%
# 84%
# 16%
# 4%
# 29%
# 67%
# 0%
# 80%
# 20%
# 4%
# 41%
# 55%
# 0%
# 80%
# 20%
# 4%
# 34%
# 62%
#
#
#
#
#
#
# 1%
# 93%
# 6%
# 7%
# 34%
# 59%
# 1%
# 93%
# 6%
# 4%
# 31%
# 65%
# 1%
# 90%
# 9%
# 6%
# 44%
# 50%
# 1%
# 90%
# 9%
# 7%
# 45%
# 48%
#
#
#
#
#
#
# 0%
# 85%
# 15%
# 5%
# 43%
# 52%
# 0%
# 83%
# 17%
# 4%
# 42%
# 54%
# 0%
# 79%
# 21%
# 4%
# 44%
# 52%
# 0%
# 81%
# 19%
# 3%
# 42%
# 55%
#
#
#
#
#
#
# 1%
# 87%
# 12%
# 7%
# 38%
# 55%
# 1%
# 87%
# 12%
# 4%
# 35%
# 61%
# 0%
# 84%
# 16%
# 5%
# 40%
# 55%
# 0%
# 86%
# 14%
# 4%
# 38%
# 58%
# 1%
# 89%
# 10%
# 6%
# 41%
# 53%
#
# 84%
# 16%
# 4%
# 29%
# 67%
# 1%
# 93%
# 6%
# 4%
# 31%
# 65%
#
# 83%
# 17%
# 4%
# 42%
# 54%
#
#
#
#
#
#
# 1%
# 88%
# 11%
# 4%
# 31%
# 65%
#
# 80%
# 20%
# 4%
# 36%
# 60%
# 1%
# 90%
# 9%
# 7%
# 44%
# 49%

# %% [markdown]
# ## 各方向合計

# %%
ele_total = soup.select('tbody tr td.xl74')
print len(ele_total)

for i in xrange(0,len(ele_total)):
    print ele_total[i].text
# Out:
# 47
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 131
#
# 10
# 58
# 824
# 1355
# 1516
#
# 15
# 0
# 239
# 93
# 350
#
# 83
# 1063
# 1448
# 1866
